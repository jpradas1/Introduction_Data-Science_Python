# %% [markdown]
# # Merging DataFrames

# %%
# In this episode we gonna use the pandas' merge function
import pandas as pd
# first let's create some dataframes
staff_df = pd.DataFrame([{'Name': 'Kelly', 'Role': 'Director of HR'},
                         {'Name': 'Sally', 'Role': 'Course liasion'},
                         {'Name': 'James', 'Role': 'Grader'}])
# and lets index these staff by name
staff_df = staff_df.set_index('Name')
# the another dataframe
student_df = pd.DataFrame([{'Name': 'James', 'School': 'Business'},
                         {'Name': 'Mike', 'School': 'Law'},
                         {'Name': 'Sally', 'School': 'Engineering'}])
# and lets index
student_df = student_df.set_index('Name')

print(staff_df.head())
print(student_df.head())
# Out:
#                  Role
# Name
# Kelly  Director of HR
# Sally  Course liasion
# James          Grader
#             School
# Name
# James     Business
# Mike           Law
# Sally  Engineering

# %%
# so to make the union of these, we gonna call merge() function
pd.merge(staff_df, student_df, how='outer', left_index=True, right_index=True)
# where we input the df we want to make a union, 'outer'
# parameter means that we choose the union operation
# and the last two parameters indicate the joining columns
# Out:
#                  Role       School
# Name
# James          Grader     Business
# Kelly  Director of HR          NaN
# Mike              NaN          Law
# Sally  Course liasion  Engineering

# %%
# To make the intersection of these, instead of 'outer' we use 'inner' parameter
pd.merge(staff_df, student_df, how='inner', left_index=True, right_index=True)
# Out:
#                  Role       School
# Name
# Sally  Course liasion  Engineering
# James          Grader     Business

# %%
# now if we want to see, for example, the staff information
# together with its school information as well we make a 
# right or left join
pd.merge(staff_df, student_df, how='left', left_index=True, right_index=True)
# becuase staff_df is the left dataframe we use left join
# Out:
#                  Role       School
# Name
# Kelly  Director of HR          NaN
# Sally  Course liasion  Engineering
# James          Grader     Business

# %%
# so as well as the previous, we can do right join
pd.merge(staff_df, student_df, how='right', left_index=True, right_index=True)
# in this case we see the student information and its related
# staff data
# Out:
#                  Role       School
# Name
# James          Grader     Business
# Mike              NaN          Law
# Sally  Course liasion  Engineering

# %%
# Also we can make this even when there's no index on df
# let's remove ourt index from both of our dataframes
staff_df = staff_df.reset_index()
student_df = student_df.reset_index()

# and now lets make the early right join
pd.merge(staff_df, student_df, how='right', on='Name')
# in this case we use the paramater 'on' to choose the
# joining column
# Out:
#     Name            Role       School
# 0  James          Grader     Business
# 1   Mike             NaN          Law
# 2  Sally  Course liasion  Engineering

# %%
# Now what happends when we have conflicts
staff_df = pd.DataFrame([{'Name': 'Kelly', 'Role': 'Director of HR', 
                          'Location': 'State Street'},
                         {'Name': 'Sally', 'Role': 'Course liasion', 
                          'Location': 'Washington Avenue'},
                         {'Name': 'James', 'Role': 'Grader', 
                          'Location': 'Washington Avenue'}])
student_df = pd.DataFrame([{'Name': 'James', 'School': 'Business', 
                            'Location': '1024 Billiard Avenue'},
                           {'Name': 'Mike', 'School': 'Law', 
                            'Location': 'Fraternity House #22'},
                           {'Name': 'Sally', 'School': 'Engineering', 
                            'Location': '512 Wilson Crescent'}])
# in this case, staff's location is the office address,
# but the student's location is the home address
# so when we make a join, pandas will create two differents
# columns to store both directions
pd.merge(staff_df, student_df, how='left', on='Name')
# Out:
#     Name            Role         Location_x       School            Location_y
# 0  Kelly  Director of HR       State Street          NaN                   NaN
# 1  Sally  Course liasion  Washington Avenue  Engineering   512 Wilson Crescent
# 2  James          Grader  Washington Avenue     Business  1024 Billiard Avenue

# %%
# let's see now how works multi-index and multiple columns
staff_df = pd.DataFrame([{'First Name': 'Kelly', 'Last Name': 'Desjardins', 
                          'Role': 'Director of HR'},
                         {'First Name': 'Sally', 'Last Name': 'Brooks', 
                          'Role': 'Course liasion'},
                         {'First Name': 'James', 'Last Name': 'Wilde', 
                          'Role': 'Grader'}])
student_df = pd.DataFrame([{'First Name': 'James', 'Last Name': 'Hammond', 
                            'School': 'Business'},
                           {'First Name': 'Mike', 'Last Name': 'Smith', 
                            'School': 'Law'},
                           {'First Name': 'Sally', 'Last Name': 'Brooks', 
                            'School': 'Engineering'}])
# so depeding of which index we pass to pandas, there will be
# data that overlaping. In these cases we pass both index
pd.merge(staff_df, student_df, how='inner', on=['First Name', 'Last Name'])
# here we have applied union operation
# Out:
#   First Name Last Name            Role       School
# 0      Sally    Brooks  Course liasion  Engineering

# %%
# now let's concate some dataframe
# %%capture # we write that for avoid error masseges from jupyter
# df_2012 = pd.read_csv("Datasets/college_scorecard/MERGED2012_13_PP.csv", error_bad_lines=False)
# df_2013 = pd.read_csv("Datasets/college_scorecard/MERGED2013_14_PP.csv", error_bad_lines=False)

# %%
# df_2012.head()

# %% [markdown]
# # Pandas Idioms

# %%
import numpy as np
import timeit

df = pd.read_csv('Datasets/census.csv')
df.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  RDOMESTICMIG2011  \
# 0        4779736            4780127          4785161  ...          0.002295
# 1          54571              54571            54660  ...          7.242091
# 2         182265             182265           183193  ...         14.832960
# 3          27457              27457            27341  ...         -4.728132
# 4          22915              22919            22861  ...         -5.527043
#
#    RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  RDOMESTICMIG2015  \
# ...

# %%
# so let's clean the data
(df.where(df['SUMLEV']==50)
    .dropna()
    .set_index(['STNAME', 'CTYNAME'])
    .rename(columns={'ESTIMATESBASE2010': 'Estimates Bases 2010'}))
# Out:
#                            SUMLEV  REGION  DIVISION  STATE  COUNTY  \
# STNAME  CTYNAME
# Alabama Autauga County       50.0     3.0       6.0    1.0     1.0
#         Baldwin County       50.0     3.0       6.0    1.0     3.0
#         Barbour County       50.0     3.0       6.0    1.0     5.0
#         Bibb County          50.0     3.0       6.0    1.0     7.0
#         Blount County        50.0     3.0       6.0    1.0     9.0
# ...                           ...     ...       ...    ...     ...
# Wyoming Sweetwater County    50.0     4.0       8.0   56.0    37.0
#         Teton County         50.0     4.0       8.0   56.0    39.0
#         Uinta County         50.0     4.0       8.0   56.0    41.0
#         Washakie County      50.0     4.0       8.0   56.0    43.0
#         Weston County        50.0     4.0       8.0   56.0    45.0
#
#                            CENSUS2010POP  Estimates Bases 2010  \
# STNAME  CTYNAME
# ...

# %%
# and we get a similar result by performing
df = df[df['SUMLEV']==50]
df.set_index(['STNAME', 'CTYNAME'], inplace=True)
df.rename(columns={'ESTIMATESBASE2010': 'Estimates Bases 2010'})
# Out:
#                            SUMLEV  REGION  DIVISION  STATE  COUNTY  \
# STNAME  CTYNAME
# Alabama Autauga County         50       3         6      1       1
#         Baldwin County         50       3         6      1       3
#         Barbour County         50       3         6      1       5
#         Bibb County            50       3         6      1       7
#         Blount County          50       3         6      1       9
# ...                           ...     ...       ...    ...     ...
# Wyoming Sweetwater County      50       4         8     56      37
#         Teton County           50       4         8     56      39
#         Uinta County           50       4         8     56      41
#         Washakie County        50       4         8     56      43
#         Weston County          50       4         8     56      45
#
#                            CENSUS2010POP  Estimates Bases 2010  \
# STNAME  CTYNAME
# ...

# %%
# so to know what method is faster we gonna use the timeit library
def first_approach():
    global df
    
    return (df.where(df['SUMLEV']==50)
              .dropna()
              .set_index(['STNAME', 'CTYNAME'])
              .rename(columns={'ESTIMATESBASE2010': 'Estimates Bases 2010'}))

df = pd.read_csv('Datasets/census.csv')

timeit.timeit(first_approach, number=10)
# Out:
# 0.4244719449998229

# %%
# so the second method goes as
def second_approach():
    global df
    new_df = df[df['SUMLEV']==50]
    new_df.set_index(['STNAME', 'CTYNAME'], inplace=True)
    return new_df.rename(columns={'ESTIMATESBASE2010': 'Estimates Bases 2010'})

df = pd.read_csv('Datasets/census.csv')

timeit.timeit(second_approach, number=10)
# Out:
# 0.083703347001574

# %%
# let's create a function that returns the maximun and minimun
def min_max(row):
    data = row[['POPESTIMATE2010',
                'POPESTIMATE2011',
                'POPESTIMATE2012',
                'POPESTIMATE2013',
                'POPESTIMATE2014',
                'POPESTIMATE2015']]
    return pd.Series({'min': np.min(data), 'max':np.max(data)})

# %%
df.apply(min_max, axis='columns').head()
# Out:
#        min      max
# 0  4785161  4858979
# 1    54660    55347
# 2   183193   203709
# 3    26489    27341
# 4    22512    22861

# %%
# again, there's another way to solve this
def min_max(row):
    data = row[['POPESTIMATE2010',
                'POPESTIMATE2011',
                'POPESTIMATE2012',
                'POPESTIMATE2013',
                'POPESTIMATE2014',
                'POPESTIMATE2015']]
    row['max'] = np.max(data)
    row['min'] = np.min(data)
    return row

df.apply(min_max, axis='columns')
# Out:
#       SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME            CTYNAME  \
# 0         40       3         6      1       0  Alabama            Alabama
# 1         50       3         6      1       1  Alabama     Autauga County
# 2         50       3         6      1       3  Alabama     Baldwin County
# 3         50       3         6      1       5  Alabama     Barbour County
# 4         50       3         6      1       7  Alabama        Bibb County
# ...      ...     ...       ...    ...     ...      ...                ...
# 3188      50       4         8     56      37  Wyoming  Sweetwater County
# 3189      50       4         8     56      39  Wyoming       Teton County
# 3190      50       4         8     56      41  Wyoming       Uinta County
# 3191      50       4         8     56      43  Wyoming    Washakie County
# 3192      50       4         8     56      45  Wyoming      Weston County
#
#       CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  \
# ...

# %%
# and again, we can use lambdas to find the max values
rows = ['POPESTIMATE2010', 'POPESTIMATE2011', 'POPESTIMATE2012',
        'POPESTIMATE2013', 'POPESTIMATE2014', 'POPESTIMATE2015']

df.apply(lambda x: np.max(x[rows]), axis=1).head()
# Out:
# 0    4858979
# 1      55347
# 2     203709
# 3      27341
# 4      22861
# dtype: int64

# %%
# let's treat whit another example
def get_state_region(x):
    northeast = ['Connecticut', 'Maine', 'Massachusetts', 'New Hampshire', 
                 'Rhode Island','Vermont','New York','New Jersey','Pennsylvania']
    midwest = ['Illinois','Indiana','Michigan','Ohio','Wisconsin','Iowa',
               'Kansas','Minnesota','Missouri','Nebraska','North Dakota',
               'South Dakota']
    south = ['Delaware','Florida','Georgia','Maryland','North Carolina',
             'South Carolina','Virginia','District of Columbia','West Virginia',
             'Alabama','Kentucky','Mississippi','Tennessee','Arkansas',
             'Louisiana','Oklahoma','Texas']
    west = ['Arizona','Colorado','Idaho','Montana','Nevada','New Mexico','Utah',
            'Wyoming','Alaska','California','Hawaii','Oregon','Washington']
    
    if x in northeast:
        return "Northeast"
    elif x in midwest:
        return "Midwest"
    elif x in south:
        return "South"
    else:
        return "West"

# %%
# so, if we want sort data in fucntion of its direction
df['state_region'] = df['STNAME'].apply(lambda x: get_state_region(x))

# %%
# and the result is
df[['STNAME','state_region']].head()
# Out:
#     STNAME state_region
# 0  Alabama        South
# 1  Alabama        South
# 2  Alabama        South
# 3  Alabama        South
# 4  Alabama        South

# %% [markdown]
# # Group by

# %%
# let's see some function

# %% [markdown]
# ## Splitting

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('Datasets/census.csv')
df = df[df['SUMLEV']==50]
df.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
# 5      50       3         6      1       9  Alabama   Blount County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  RDOMESTICMIG2011  \
# 1          54571              54571            54660  ...          7.242091
# 2         182265             182265           183193  ...         14.832960
# 3          27457              27457            27341  ...         -4.728132
# 4          22915              22919            22861  ...         -5.527043
# 5          57322              57322            57373  ...          1.807375
#
#    RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  RDOMESTICMIG2015  \
# ...

# %%
# %%timeit -n 3

for state in df['STNAME'].unique():
    avg = np.average(df.where(df['STNAME']==state).dropna()['CENSUS2010POP'])
    
    print('Counties in state ' + state +
          ' have an average population of ' + str(avg))
# Out:
# Counties in state Alabama have an average population of 71339.34328358209
# Counties in state Alaska have an average population of 24490.724137931036
# Counties in state Arizona have an average population of 426134.4666666667
# Counties in state Arkansas have an average population of 38878.90666666667
# Counties in state California have an average population of 642309.5862068966
# Counties in state Colorado have an average population of 78581.1875
# Counties in state Connecticut have an average population of 446762.125
# Counties in state Delaware have an average population of 299311.3333333333
# Counties in state District of Columbia have an average population of 601723.0
# Counties in state Florida have an average population of 280616.5671641791
# Counties in state Georgia have an average population of 60928.63522012578
# Counties in state Hawaii have an average population of 272060.2
# Counties in state Idaho have an average population of 35626.86363636364
# ...

# %%
# %%timeit -n 3
# now, let's try another approching 

for group, frame in df.groupby('STNAME'):
    # this split data, where 'group' parameter has the information of state
    # and 'frame' the information related with that state (group)
    
    # in this we access to 'CENSUS2010POP' stored in frame parameter
    avg = np.average(frame['CENSUS2010POP'])
    
    print('Counties in state ' + group +
          ' have an average population of ' + str(avg))
# Out:
# Counties in state Alabama have an average population of 71339.34328358209
# Counties in state Alaska have an average population of 24490.724137931036
# Counties in state Arizona have an average population of 426134.4666666667
# Counties in state Arkansas have an average population of 38878.90666666667
# Counties in state California have an average population of 642309.5862068966
# Counties in state Colorado have an average population of 78581.1875
# Counties in state Connecticut have an average population of 446762.125
# Counties in state Delaware have an average population of 299311.3333333333
# Counties in state District of Columbia have an average population of 601723.0
# Counties in state Florida have an average population of 280616.5671641791
# Counties in state Georgia have an average population of 60928.63522012578
# Counties in state Hawaii have an average population of 272060.2
# Counties in state Idaho have an average population of 35626.86363636364
# ...

# %%
df = df.set_index('STNAME')

def set_batch_number(item):
    if item[0]<'M':
        return 0
    if item[0]<'Q':
        return 1
    return 2

for group, frame in df.groupby(set_batch_number):
    print('There are ' + str(len(frame)) + ' records in group ' + str(group) + ' for processing.')
# Out:
# There are 1177 records in group 0 for processing.
# There are 1134 records in group 1 for processing.
# There are 831 records in group 2 for processing.

# %%
# let's take another dataframe

df = pd.read_csv('Datasets/listings.csv')
df.head()
# Out:
#          id                            listing_url       scrape_id  \
# 0  12147973  https://www.airbnb.com/rooms/12147973  20160906204935
# 1   3075044   https://www.airbnb.com/rooms/3075044  20160906204935
# 2      6976      https://www.airbnb.com/rooms/6976  20160906204935
# 3   1436513   https://www.airbnb.com/rooms/1436513  20160906204935
# 4   7651065   https://www.airbnb.com/rooms/7651065  20160906204935
#
#   last_scraped                                           name  \
# 0   2016-09-07                     Sunny Bungalow in the City
# 1   2016-09-07              Charming room in pet friendly apt
# 2   2016-09-07               Mexican Folk Art Haven in Boston
# 3   2016-09-07  Spacious Sunny Bedroom Suite in Historic Home
# 4   2016-09-07                            Come Home to Boston
#
#                                              summary  \
# 0  Cozy, sunny, family home.  Master bedroom high...
# 1  Charming and quiet room in a second floor 1910...
# ...

# %%
# to group by, we first choose some index
df = df.set_index(["cancellation_policy","review_scores_value"])

for group, frame in df.groupby(level=(0,1)):
    print(group)
# Out:
# ('flexible', 2.0)
# ('flexible', 4.0)
# ('flexible', 5.0)
# ('flexible', 6.0)
# ('flexible', 7.0)
# ('flexible', 8.0)
# ('flexible', 9.0)
# ('flexible', 10.0)
# ('moderate', 2.0)
# ('moderate', 4.0)
# ('moderate', 6.0)
# ('moderate', 7.0)
# ('moderate', 8.0)
# ('moderate', 9.0)
# ('moderate', 10.0)
# ('strict', 2.0)
# ('strict', 3.0)
# ('strict', 4.0)
# ('strict', 5.0)
# ('strict', 6.0)
# ('strict', 7.0)
# ('strict', 8.0)
# ('strict', 9.0)
# ('strict', 10.0)
# ('super_strict_30', 6.0)
# ('super_strict_30', 7.0)
# ('super_strict_30', 8.0)
# ('super_strict_30', 9.0)
# ('super_strict_30', 10.0)

# %%
# on the other hand
def grouping_fun(item):
    if item[1] == 10.0:
        return (item[0],"10.0")
    else:
        return (item[0],"not 10.0")
    
for group, frame in df.groupby(by=grouping_fun):
    print(group)
# Out:
# ('flexible', '10.0')
# ('flexible', 'not 10.0')
# ('moderate', '10.0')
# ('moderate', 'not 10.0')
# ('strict', '10.0')
# ('strict', 'not 10.0')
# ('super_strict_30', '10.0')
# ('super_strict_30', 'not 10.0')

# %%
df.head()
# Out:
#                                                id  \
# cancellation_policy review_scores_value
# moderate            NaN                  12147973
#                     9.0                   3075044
#                     10.0                     6976
#                     10.0                  1436513
# flexible            10.0                  7651065
#
#                                                                    listing_url  \
# cancellation_policy review_scores_value
# moderate            NaN                  https://www.airbnb.com/rooms/12147973
#                     9.0                   https://www.airbnb.com/rooms/3075044
#                     10.0                     https://www.airbnb.com/rooms/6976
#                     10.0                  https://www.airbnb.com/rooms/1436513
# flexible            10.0                  https://www.airbnb.com/rooms/7651065
#
#                                               scrape_id last_scraped  \
# ...

# %% [markdown]
# ## Aggregation

# %%
# let's reset the index for our airbnb data
df = df.reset_index()

df.groupby("cancellation_policy").agg({"review_scores_value":np.average})
# Out:
#                      review_scores_value
# cancellation_policy
# flexible                             NaN
# moderate                             NaN
# strict                               NaN
# super_strict_30                      NaN

# %%
# it seems that didn't work
df.groupby("cancellation_policy").agg({"review_scores_value":np.nanmean})
# Out:
#                      review_scores_value
# cancellation_policy
# flexible                        9.237421
# moderate                        9.307398
# strict                          9.081441
# super_strict_30                 8.537313

# %%
# we can also include more columns
df.groupby("cancellation_policy").agg({"review_scores_value":(np.nanmean,np.nanstd),
                                       "reviews_per_month":np.nanmean})
# Out:
#                     review_scores_value           reviews_per_month
#                                 nanmean    nanstd           nanmean
# cancellation_policy
# flexible                       9.237421  1.096271          1.829210
# moderate                       9.307398  0.859859          2.391922
# strict                         9.081441  1.040531          1.873467
# super_strict_30                8.537313  0.840785          0.340143

# %% [markdown]
# ## Transformation

# %%
# Transformation is different from aggregation
# first, let's make a subset of information we are interested in
cols = ['cancellation_policy','review_scores_value']

transform_df = df[cols].groupby('cancellation_policy').transform(np.nanmean)
transform_df.head()
# Out:
#    review_scores_value
# 0             9.307398
# 1             9.307398
# 2             9.307398
# 3             9.307398
# 4             9.237421

# %%
# so if we want change the name of the column
transform_df.rename({'review_scores_value':'mean_review_scores'}, axis='columns', inplace=True)
df = df.merge(transform_df, left_index=True, right_index=True)
df.head()
# Out:
#   cancellation_policy  review_scores_value        id  \
# 0            moderate                  NaN  12147973
# 1            moderate                  9.0   3075044
# 2            moderate                 10.0      6976
# 3            moderate                 10.0   1436513
# 4            flexible                 10.0   7651065
#
#                              listing_url       scrape_id last_scraped  \
# 0  https://www.airbnb.com/rooms/12147973  20160906204935   2016-09-07
# 1   https://www.airbnb.com/rooms/3075044  20160906204935   2016-09-07
# 2      https://www.airbnb.com/rooms/6976  20160906204935   2016-09-07
# 3   https://www.airbnb.com/rooms/1436513  20160906204935   2016-09-07
# 4   https://www.airbnb.com/rooms/7651065  20160906204935   2016-09-07
#
#                                             name  \
# 0                     Sunny Bungalow in the City
# 1              Charming room in pet friendly apt
# 2               Mexican Folk Art Haven in Boston
# ...

# %%
# so we can perform some operations on it
df['mean_diff'] = np.absolute(df['review_scores_value']-df['mean_review_scores'])

# %%
df['mean_diff'].head()
# Out:
# 0         NaN
# 1    0.307398
# 2    0.692602
# 3    0.692602
# 4    0.762579
# Name: mean_diff, dtype: float64

# %% [markdown]
# ## Filtering

# %%
# now we can combine the earlier work and filter the resulting information
# for example
df.groupby('cancellation_policy').filter(lambda x: np.nanmean(x['review_scores_value'])>9.2)
# Out:
#      cancellation_policy  review_scores_value        id  \
# 0               moderate                  NaN  12147973
# 1               moderate                  9.0   3075044
# 2               moderate                 10.0      6976
# 3               moderate                 10.0   1436513
# 4               flexible                 10.0   7651065
# ...                  ...                  ...       ...
# 3576            flexible                  NaN  14689681
# 3577            flexible                  NaN  13750763
# 3579            flexible                  NaN  14852179
# 3582            flexible                  NaN  14585486
# 3584            flexible                  NaN  14504422
#
#                                 listing_url       scrape_id last_scraped  \
# 0     https://www.airbnb.com/rooms/12147973  20160906204935   2016-09-07
# 1      https://www.airbnb.com/rooms/3075044  20160906204935   2016-09-07
# ...

# %% [markdown]
# ## Applying

# %%
# first let us choose two columns
df = pd.read_csv("Datasets/listings.csv")
df = df[['cancellation_policy','review_scores_value']]
df.head()
# Out:
#   cancellation_policy  review_scores_value
# 0            moderate                  NaN
# 1            moderate                  9.0
# 2            moderate                 10.0
# 3            moderate                 10.0
# 4            flexible                 10.0

# %%
def calc_mean_review_scores(group):
    
    avg = np.nanmean(group["review_scores_value"])
    group["review_scores_mean"] = np.abs(avg-group["review_scores_value"])
    return group

df.groupby('cancellation_policy').apply(calc_mean_review_scores).head()
# Out:
# /tmp/ipykernel_26296/3202077524.py:7: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   df.groupby('cancellation_policy').apply(calc_mean_review_scores).head()
#   cancellation_policy  review_scores_value  review_scores_mean
# 0            moderate                  NaN                 NaN
# 1            moderate                  9.0            0.307398
# 2            moderate                 10.0            0.692602
# 3            moderate                 10.0            0.692602
# 4            flexible                 10.0            0.762579

# %% [markdown]
# # Scales

# %%
# let's get started by importing pandas
import pandas as pd

df=pd.DataFrame(['A+', 'A', 'A-', 'B+', 'B', 'B-', 'C+', 'C', 'C-', 'D+', 'D'],
                index=['excellent', 'excellent', 'excellent', 'good', 'good', 'good', 
                       'ok', 'ok', 'ok', 'poor', 'poor'],
               columns=["Grades"])

df
# Out:
#           Grades
# excellent     A+
# excellent      A
# excellent     A-
# good          B+
# good           B
# good          B-
# ok            C+
# ok             C
# ok            C-
# poor          D+
# poor           D

# %%
# we see that the type of this data is
df.dtypes
# Out:
# Grades    object
# dtype: object

# %%
# so, we can change it
df["Grades"].astype("category").head()
# Out:
# excellent    A+
# excellent     A
# excellent    A-
# good         B+
# good          B
# Name: Grades, dtype: category
# Categories (11, object): ['A', 'A+', 'A-', 'B', ..., 'C+', 'C-', 'D', 'D+']

# %%
# with this, we can order this categories, for example
my_categories = pd.CategoricalDtype(categories=['D', 'D+', 'C-', 'C', 'C+', 'B-', 'B', 'B+', 'A-', 'A', 'A+'], 
                           ordered=True)
grades = df["Grades"].astype(my_categories)
grades.head()
# Out:
# excellent    A+
# excellent     A
# excellent    A-
# good         B+
# good          B
# Name: Grades, dtype: category
# Categories (11, object): ['D' < 'D+' < 'C-' < 'C' ... 'B+' < 'A-' < 'A' < 'A+']

# %%
# so to filter data
df[df["Grades"]>"C"]
# Out:
#      Grades
# ok       C+
# ok       C-
# poor     D+
# poor      D

# %%
# but C-, D+ and D are not greater than C, so for this we use categories
grades[grades>"C"]
# Out:
# excellent    A+
# excellent     A
# excellent    A-
# good         B+
# good          B
# good         B-
# ok           C+
# Name: Grades, dtype: category
# Categories (11, object): ['D' < 'D+' < 'C-' < 'C' ... 'B+' < 'A-' < 'A' < 'A+']

# %%
# now, let's bring in numpy
import numpy as np

df = pd.read_csv("Datasets/census.csv")
# reducing the data
df = df[df['SUMLEV']==50]

df = df.set_index('STNAME').groupby(level=0)['CENSUS2010POP']#.agg(np.average)

df.head()
# Out:
# STNAME
# Alabama     54571
# Alabama    182265
# Alabama     27457
# Alabama     22915
# Alabama     57322
#             ...
# Wyoming     36299
# Wyoming     11668
# Wyoming     46133
# Wyoming     15885
# Wyoming     13833
# Name: CENSUS2010POP, Length: 249, dtype: int64

# %%
# and we use 'cut' attribute
pd.cut(df,10)
# Out:
# STNAME
# Alabama                   (11706.087, 75333.413]
# Alaska                    (11706.087, 75333.413]
# Arizona                 (390320.176, 453317.529]
# Arkansas                  (11706.087, 75333.413]
# California              (579312.234, 642309.586]
# Colorado                 (75333.413, 138330.766]
# Connecticut             (390320.176, 453317.529]
# Delaware                (264325.471, 327322.823]
# District of Columbia    (579312.234, 642309.586]
# Florida                 (264325.471, 327322.823]
# Georgia                   (11706.087, 75333.413]
# Hawaii                  (264325.471, 327322.823]
# Idaho                     (11706.087, 75333.413]
# Illinois                 (75333.413, 138330.766]
# Indiana                   (11706.087, 75333.413]
# Iowa                      (11706.087, 75333.413]
# Kansas                    (11706.087, 75333.413]
# Kentucky                  (11706.087, 75333.413]
# Louisiana                 (11706.087, 75333.413]
# ...

# %% [markdown]
# # Pivot Table

# %%
# lets take a look at pivot tables
import pandas as pd
import numpy as np

df = pd.read_csv('Datasets/cwurData.csv')
df.head()
# Out:
#    world_rank                            institution         country  \
# 0           1                     Harvard University             USA
# 1           2  Massachusetts Institute of Technology             USA
# 2           3                    Stanford University             USA
# 3           4                University of Cambridge  United Kingdom
# 4           5     California Institute of Technology             USA
#
#    national_rank  quality_of_education  alumni_employment  quality_of_faculty  \
# 0              1                     7                  9                   1
# 1              2                     9                 17                   3
# 2              3                    17                 11                   5
# 3              1                    10                 24                   4
# 4              4                     2                 29                   7
#
#    publications  influence  citations  broad_impact  patents   score  year
# ...

# %%
# now let's sort data depend of university ranking

def create_category(ranking):
    if (ranking >= 1) & (ranking <= 100):
        return "First Tier Top University"
    elif (ranking >= 101) & (ranking <= 200):
        return "Second Tier Top University"
    elif (ranking >= 201) & (ranking <= 300):
        return "Third Tier Top University"
    return "Other Top University"

df['Rank_Level'] = df['world_rank'].apply(lambda x: create_category(x))
df.head()
# Out:
#    world_rank                            institution         country  \
# 0           1                     Harvard University             USA
# 1           2  Massachusetts Institute of Technology             USA
# 2           3                    Stanford University             USA
# 3           4                University of Cambridge  United Kingdom
# 4           5     California Institute of Technology             USA
#
#    national_rank  quality_of_education  alumni_employment  quality_of_faculty  \
# 0              1                     7                  9                   1
# 1              2                     9                 17                   3
# 2              3                    17                 11                   5
# 3              1                    10                 24                   4
# 4              4                     2                 29                   7
#
#    publications  influence  citations  broad_impact  patents   score  year  \
# ...

# %%
# to perform a pivot
df.pivot_table(values='score', index='country', columns='Rank_Level', aggfunc=[np.mean]).head(20)
# Out:
#                                     mean                       \
# Rank_Level     First Tier Top University Other Top University
# country
# Argentina                            NaN            44.672857
# Australia                      47.942500            44.645750
# Austria                              NaN            44.864286
# Belgium                        51.875000            45.081000
# Brazil                               NaN            44.499706
# Bulgaria                             NaN            44.335000
# Canada                         53.633846            44.760541
# Chile                                NaN            44.767500
# China                          53.592500            44.564267
# Colombia                             NaN            44.432500
# Croatia                              NaN            44.770000
# Cyprus                               NaN            44.210000
# Czech Republic                       NaN            44.587778
# ...

# %%
# the earlier is the mean university ranking value of each country per category,
# and we can add the maximun value
df.pivot_table(values='score', index='country', columns='Rank_Level', aggfunc=[np.mean, np.max]).head(20)
# Out:
#                                     mean                       \
# Rank_Level     First Tier Top University Other Top University
# country
# Argentina                            NaN            44.672857
# Australia                      47.942500            44.645750
# Austria                              NaN            44.864286
# Belgium                        51.875000            45.081000
# Brazil                               NaN            44.499706
# Bulgaria                             NaN            44.335000
# Canada                         53.633846            44.760541
# Chile                                NaN            44.767500
# China                          53.592500            44.564267
# Colombia                             NaN            44.432500
# Croatia                              NaN            44.770000
# Cyprus                               NaN            44.210000
# Czech Republic                       NaN            44.587778
# ...

# %%
# and to add the general average
df.pivot_table(values='score', index='country', columns='Rank_Level', aggfunc=[np.mean, np.max],
               margins=True).head(20)
# Out:
#                                     mean                       \
# Rank_Level     First Tier Top University Other Top University
# country
# Argentina                            NaN            44.672857
# Australia                      47.942500            44.645750
# Austria                              NaN            44.864286
# Belgium                        51.875000            45.081000
# Brazil                               NaN            44.499706
# Bulgaria                             NaN            44.335000
# Canada                         53.633846            44.760541
# Chile                                NaN            44.767500
# China                          53.592500            44.564267
# Colombia                             NaN            44.432500
# Croatia                              NaN            44.770000
# Cyprus                               NaN            44.210000
# Czech Republic                       NaN            44.587778
# ...

# %%
# let's create a new df from our previous example
new_df = df.pivot_table(values='score', index='country', columns='Rank_Level', aggfunc=[np.mean, np.max],
               margins=True).head(20)
print(new_df.index)
print(new_df.columns)
# Out:
# Index(['Argentina', 'Australia', 'Austria', 'Belgium', 'Brazil', 'Bulgaria',
#        'Canada', 'Chile', 'China', 'Colombia', 'Croatia', 'Cyprus',
#        'Czech Republic', 'Denmark', 'Egypt', 'Estonia', 'Finland', 'France',
#        'Germany', 'Greece'],
#       dtype='object', name='country')
# MultiIndex([('mean',  'First Tier Top University'),
#             ('mean',       'Other Top University'),
#             ('mean', 'Second Tier Top University'),
#             ('mean',  'Third Tier Top University'),
#             ('mean',                        'All'),
#             ('amax',  'First Tier Top University'),
#             ('amax',       'Other Top University'),
#             ('amax', 'Second Tier Top University'),
#             ('amax',  'Third Tier Top University'),
#             ('amax',                        'All')],
#            names=[None, 'Rank_Level'])

# %%
# so to check the mean value of the first top U
new_df['mean']['First Tier Top University'].head()
# Out:
# country
# Argentina        NaN
# Australia    47.9425
# Austria          NaN
# Belgium      51.8750
# Brazil           NaN
# Name: First Tier Top University, dtype: float64

# %%
# and the type is
type(new_df['mean']['First Tier Top University'])
# Out:
# pandas.core.series.Series

# %%
# so if we want to know the country which has the maximun value
# on First TTU
new_df['mean']['First Tier Top University'].idxmax()
# Out:
# 'Canada'

# %%
# Now coming back to new df we can use the stack and unstack
# to summary the data
new_df = new_df.stack()
new_df.head()
# Out:
#                                            mean   amax
# country   Rank_Level
# Argentina Other Top University        44.672857  45.66
#           All                         44.672857  45.66
# Australia First Tier Top University   47.942500  51.61
#           Other Top University        44.645750  45.97
#           Second Tier Top University  49.242500  50.40

# %%
# and to restore original new df
new_df.unstack().head()
# Out:
#                                 mean                       \
# Rank_Level First Tier Top University Other Top University
# country
# Argentina                        NaN            44.672857
# Australia                    47.9425            44.645750
# Austria                          NaN            44.864286
# Belgium                      51.8750            45.081000
# Brazil                           NaN            44.499706
#
#                                                                             \
# Rank_Level Second Tier Top University Third Tier Top University        All
# country
# Argentina                         NaN                       NaN  44.672857
# Australia                     49.2425                 47.285000  45.825517
# Austria                           NaN                 47.066667  45.139583
# Belgium                       49.0840                 46.746667  47.011000
# Brazil                        49.5650                       NaN  44.781111
#
# ...

# %%
# and when we apply twice the unstack function
new_df.unstack().unstack().head()
# Out:
#       Rank_Level                 country
# mean  First Tier Top University  Argentina        NaN
#                                  Australia    47.9425
#                                  Austria          NaN
#                                  Belgium      51.8750
#                                  Brazil           NaN
# dtype: float64

# %% [markdown]
# # Date/Time Functionality

# %%
# let's bring in pandas and numpy as usual
import pandas as pd
import numpy as np

# %%
# using pandas we can do a timestamp
pd.Timestamp('9/1/2019 10:05AM')
# Out:
# Timestamp('2019-09-01 10:05:00')

# %%
# also we can create it separately
pd.Timestamp(2019, 12, 20, 0, 0)
# Out:
# Timestamp('2019-12-20 00:00:00')

# %%
# this has some useful attributes, for example
pd.Timestamp(2019, 12, 20, 0, 0).isoweekday()
# to pandas, 1 is monday and 7 is sunday
# Out:
# 5

# %%
# we can extract the specific information we want to, 
pd.Timestamp(2019, 12, 20, 5, 2, 23).second
# Out:
# 23

# %% [markdown]
# ## Period

# %%
# we can create a perios per month or day
pd.Period('1/2016')
# Out:
# Period('2016-01', 'M')

# %%
# per day
pd.Period('3/5/2016')
# Out:
# Period('2016-03-05', 'D')

# %%
# with this we can make aritmetic, e.g.,
pd.Period('1/2016') + 5
# and we obtain 5 month ahead of January
# Out:
# Period('2016-06', 'M')

# %%
# and substracting
pd.Period('3/5/2016') - 2
# this time we have obtained two days back
# Out:
# Period('2016-03-03', 'D')

# %% [markdown]
# ## DatetimeIndex and PeriodIndex

# %%
# let's make a pandas series
t1 = pd.Series(list('abc'), [pd.Timestamp('2016-09-01'), pd.Timestamp('2016-09-02'),
                             pd.Timestamp('2016-09-03')])
t1
# Out:
# 2016-09-01    a
# 2016-09-02    b
# 2016-09-03    c
# dtype: object

# %%
# and its index type
type(t1.index)
# this is a Datatime Index
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %%
# but there's also a Period Index
t2 = pd.Series(list('def'), [pd.Period('2016-09'), pd.Period('2016-10'),
                             pd.Period('2016-11')])
t2
# Out:
# 2016-09    d
# 2016-10    e
# 2016-11    f
# Freq: M, dtype: object

# %%
type(t2.index)
# Out:
# pandas.core.indexes.period.PeriodIndex

# %% [markdown]
# ## Converting to Datetime

# %%
# now, we can convert any date form to Datetime
d1 = ['2 June 2013', 'Aug 29, 2014', '2015-06-26', '7/12/16']

# random data
ts3 = pd.DataFrame(np.random.randint(10, 100, (4,2)), index=d1,
                   columns=list('ab'))
ts3
# Out:
#                a   b
# 2 June 2013   23  91
# Aug 29, 2014  15  69
# 2015-06-26    49  98
# 7/12/16       80  80

# %%
# so to convert or take a standar date
ts3.index = pd.to_datetime(ts3.index)
ts3
# Out:
#              a   b
# 2013-06-02  23  91
# 2014-08-29  15  69
# 2015-06-26  49  98
# 2016-07-12  80  80

# %%
# however to convert date of the Europe form, we would do
pd.to_datetime('4.7.12', dayfirst=True)
# Out:
# Timestamp('2012-07-04 00:00:00')

# %% [markdown]
# ## Timedelta

# %%
# so, if we want to know the day between to days 
pd.Timestamp('9/3/2016') - pd.Timestamp('9/1/2016')
# Out:
# Timedelta('2 days 00:00:00')

# %%
# and we can add a preciser date
pd.Timestamp('9/2/2016 8:10AM') + pd.Timedelta('12D 3H')
# Out:
# Timestamp('2016-09-14 11:10:00')

# %% [markdown]
# ## Offset

# %%
# On the other hand, from a date we can know what day of week is
pd.Timestamp('9/4/2016').weekday()
# Out:
# 6

# %%
# or to add a week ahead
pd.Timestamp('9/4/2016') + pd.offsets.Week()
# Out:
# Timestamp('2016-09-11 00:00:00')

# %%
# also we can go to month end
pd.Timestamp('9/4/2016') + pd.offsets.MonthEnd()
# Out:
# Timestamp('2016-09-30 00:00:00')

# %% [markdown]
# ## Working with Dates in a Dataframe

# %%
# now we goint to create a frecuency of dates
dates = pd.date_range('10-01-2016', periods=9, freq='2W-SUN')
dates
# Out:
# DatetimeIndex(['2016-10-02', '2016-10-16', '2016-10-30', '2016-11-13',
#                '2016-11-27', '2016-12-11', '2016-12-25', '2017-01-08',
#                '2017-01-22'],
#               dtype='datetime64[ns]', freq='2W-SUN')

# %%
# there are many other frequencies that can be specified
pd.date_range('10-01-2016', periods=9, freq='B')
# this is a range of the work days
# Out:
# DatetimeIndex(['2016-10-03', '2016-10-04', '2016-10-05', '2016-10-06',
#                '2016-10-07', '2016-10-10', '2016-10-11', '2016-10-12',
#                '2016-10-13'],
#               dtype='datetime64[ns]', freq='B')

# %%
# also it's possible make a range by months
pd.date_range('04-01-2016', periods=12, freq='QS-JUN')
# Out:
# DatetimeIndex(['2016-06-01', '2016-09-01', '2016-12-01', '2017-03-01',
#                '2017-06-01', '2017-09-01', '2017-12-01', '2018-03-01',
#                '2018-06-01', '2018-09-01', '2018-12-01', '2019-03-01'],
#               dtype='datetime64[ns]', freq='QS-JUN')

# %%
# and to introduce them into a dataframe

dates = pd.date_range('10-01-2016', periods=9, freq='2W-SUN')
df = pd.DataFrame({'Count 1': 100 + np.random.randint(-5, 10, 9).cumsum(),
                  'Count 2': 120 + np.random.randint(-5, 10, 9)}, index=dates)
df
# Out:
#             Count 1  Count 2
# 2016-10-02      104      115
# 2016-10-16      109      129
# 2016-10-30      108      116
# 2016-11-13      111      120
# 2016-11-27      106      124
# 2016-12-11      106      118
# 2016-12-25      101      116
# 2017-01-08      102      116
# 2017-01-22       98      116

# %%
# to know what day is each one
# df.index.weekday_name

# to find the differents values
df.diff()
# Out:
#             Count 1  Count 2
# 2016-10-02      NaN      NaN
# 2016-10-16      5.0     14.0
# 2016-10-30     -1.0    -13.0
# 2016-11-13      3.0      4.0
# 2016-11-27     -5.0      4.0
# 2016-12-11      0.0     -6.0
# 2016-12-25     -5.0     -2.0
# 2017-01-08      1.0      0.0
# 2017-01-22     -4.0      0.0

# %% [markdown]
# # Quiz 3

# %%
import pandas as pd
pd.Period('01/12/2019', 'M') + 5
# Out:
# Period('2019-06', 'M')
